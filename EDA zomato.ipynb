# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\SHUBHAM SHARMA\Desktop\ML Projects\EDA by krish nayak\zomato.csv',encoding='latin-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# # Data Analysis
#
# 1. Missing Values
# 2. Select numerical VAlues
# 3. Select Categorical values
# 4. Relation between features

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
plt.rcParams['figure.figsize']=(12,6)
sns.heatmap(df.isnull(),cmap='viridis',cbar=False)
# Out:
# <AxesSubplot:>

# %%
df.drop('Cuisines',axis=1,inplace=True)

# %%
# or another method to check null values
[features for features in df.columns if df[features].isnull().sum()>0]
# Out:
# ['Cuisines']

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df_country=pd.read_excel(r'C:\Users\SHUBHAM SHARMA\Desktop\ML Projects\EDA by krish nayak\Country-Code.xlsx')
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df_final=pd.merge(df,df_country,on='Country Code',how='left')
df_final.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df_final.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
# check datatypes
df_final.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
index=df_final.Country.value_counts().index

# %%
values=df_final.Country.value_counts().values

# %%
plt.pie(values[:3],labels=index[:3],autopct='%1.5f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x5b39281070>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94.39232%'),
#   Text(0.5876082086391032, -0.12131196618612707, '4.73489%'),
#   Text(0.5997744629358018, -0.01644972978715676, '0.87279%')])

# %%
rating=df_final.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating'})
rating
# Out:
#     Aggregate rating Rating color Rating text  Rating
# 0                0.0        White   Not rated    2148
# 1                1.8          Red        Poor       1
# 2                1.9          Red        Poor       2
# 3                2.0          Red        Poor       7
# 4                2.1          Red        Poor      15
# 5                2.2          Red        Poor      27
# 6                2.3          Red        Poor      47
# 7                2.4          Red        Poor      87
# 8                2.5       Orange     Average     110
# 9                2.6       Orange     Average     191
# 10               2.7       Orange     Average     250
# 11               2.8       Orange     Average     315
# 12               2.9       Orange     Average     381
# 13               3.0       Orange     Average     468
# 14               3.1       Orange     Average     519
# 15               3.2       Orange     Average     522
# ...

# %% [markdown]
# # Observations
#
# 1.most of the people rating 0.
# 2.Red color shows the rating between 1.8 to 2.4 that shows poor.
# 3.Orange color shows the rating between 2.5 to 3.4 that shows Average.
# 4.Yellow color shows the rating between 3.5 to 3.9 that shows good.
# 5.Green shows the rating between 4.0 to 4.4  that shows very good.
# 6.Dark Green color shows the rating between 4.5 to 4.9 that shows excellent.

# %%
sns.barplot('Aggregate rating','Rating',hue='Rating color',data=rating,palette=['white','red','orange','yellow','green','green'])
# Out:
# C:\Users\SHUBHAM SHARMA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating'>

# %% [markdown]
# Maximum rating is between 2.5 to 3.9

# %%
sns.countplot('Rating color',data=rating,palette=['white','red','orange','yellow','green','green'])
# Out:
# C:\Users\SHUBHAM SHARMA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rating color', ylabel='count'>

# %%
# find the countries name that has 0 ratings
df_final[df_final['Rating color']=='White'].groupby('Country').size().reset_index()
# Out:
#           Country     0
# 0          Brazil     5
# 1           India  2139
# 2  United Kingdom     1
# 3   United States     3

# %% [markdown]
# observations
# 1. maximum no of zero ratings are from Indain.

# %%
# Find out which currency is used by which country
df_final[['Country','Currency']].groupby(['Country','Currency']).count().reset_index()
# Out:
#            Country                Currency
# 0        Australia               Dollar($)
# 1           Brazil      Brazilian Real(R$)
# 2           Canada               Dollar($)
# 3            India      Indian Rupees(Rs.)
# 4        Indonesia  Indonesian Rupiah(IDR)
# 5      New Zealand           NewZealand($)
# 6      Phillipines        Botswana Pula(P)
# 7            Qatar         Qatari Rial(QR)
# 8        Singapore               Dollar($)
# 9     South Africa                 Rand(R)
# 10       Sri Lanka   Sri Lankan Rupee(LKR)
# 11          Turkey        Turkish Lira(TL)
# 12             UAE      Emirati Diram(AED)
# 13  United Kingdom              Pounds(£)
# 14   United States               Dollar($)

# %%
#which countries do have online deliveries?
a=df_final[['Country','Has Online delivery']].groupby(['Country','Has Online delivery']).size().reset_index()
a
# Out:
#            Country Has Online delivery     0
# 0        Australia                  No    24
# 1           Brazil                  No    60
# 2           Canada                  No     4
# 3            India                  No  6229
# 4            India                 Yes  2423
# 5        Indonesia                  No    21
# 6      New Zealand                  No    40
# 7      Phillipines                  No    22
# 8            Qatar                  No    20
# 9        Singapore                  No    20
# 10    South Africa                  No    60
# 11       Sri Lanka                  No    20
# 12          Turkey                  No    34
# 13             UAE                  No    32
# 14             UAE                 Yes    28
# 15  United Kingdom                  No    80
# 16   United States                  No   434

# %%
df_final[df_final['Has Online delivery']=='yes'].Country.value_counts()
# Out:
# Series([], Name: Country, dtype: int64)

# %%
a['Country'][a['Has Online delivery']=='yes'].value_counts()
# Out:
# Series([], Name: Country, dtype: int64)

# %%
# create a pie chart for top 5 cities distribution
indexx=df_final.City.value_counts().index
valuee=df_final.City.value_counts().values

# %%
plt.pie(valuee[:5],labels=indexx[:5],autopct='%1.5f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x893b2b47c0>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')],
#  [Text(-0.3352010631374145, 0.497634652402289, '68.86876%'),
#   Text(0.0340186500653484, -0.5990348332507311, '14.06820%'),
#   Text(0.47940246685229276, -0.36079533641101336, '13.59003%'),
#   Text(0.5957573682667329, -0.07122610585941394, '3.15842%'),
#   Text(0.5999706981848791, -0.005929698099289049, '0.31458%')])

# %%
# find top 10 cuisines
df_final.Cuisines.sort_values(ascending=False).reset_index().head(10)
# Out:
#    index                                Cuisines
# 0   9547         World Cuisine, Patisserie, Cafe
# 1   9525         World Cuisine, Mexican, Italian
# 2   9524                           World Cuisine
# 3    471              Western, Fusion, Fast Food
# 4   9285                    Western, Asian, Cafe
# 5   9327              Vietnamese, Fish and Chips
# 6    139                              Vietnamese
# 7   3975                              Vietnamese
# 8   3768  Turkish, Mediterranean, Middle Eastern
# 9   5935    Turkish, Arabian, Moroccan, Lebanese

# %% [markdown]
# # 2. Select numerical features

# %%
num_feature=df_final.select_dtypes(include=np.number)

# %%
num_feature
# Out:
#       Restaurant ID  Country Code   Longitude   Latitude  \
# 0           6317637           162  121.027535  14.565443
# 1           6304287           162  121.014101  14.553708
# 2           6300002           162  121.056831  14.581404
# 3           6318506           162  121.056475  14.585318
# 4           6314302           162  121.057508  14.584450
# ...             ...           ...         ...        ...
# 9546        5915730           208   28.977392  41.022793
# 9547        5908749           208   29.041297  41.009847
# 9548        5915807           208   29.034640  41.055817
# 9549        5916112           208   29.036019  41.057979
# 9550        5927402           208   29.026016  40.984776
#
#       Average Cost for two  Price range  Aggregate rating  Votes
# 0                     1100            3               4.8    314
# 1                     1200            3               4.5    591
# 2                     4000            4               4.4    270
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Average Cost for two  9551 non-null   int64
#  10  Currency              9551 non-null   object
#  11  Has Table booking     9551 non-null   object
#  12  Has Online delivery   9551 non-null   object
#  13  Is delivering now     9551 non-null   object
#  14  Switch to order menu  9551 non-null   object
# ...

# %% [markdown]
# # 3. Categorial features

# %%
cat_feature=df_final.select_dtypes(include='object')

# %%
cat_feature
# Out:
#                Restaurant Name              City  \
# 0             Le Petit Souffle       Makati City
# 1             Izakaya Kikufuji       Makati City
# 2       Heat - Edsa Shangri-La  Mandaluyong City
# 3                         Ooma  Mandaluyong City
# 4                  Sambo Kojin  Mandaluyong City
# ...                        ...               ...
# 9546              NamlÛ± Gurme         ÛÁstanbul
# 9547             Ceviz AÛôacÛ±         ÛÁstanbul
# 9548                     Huqqa         ÛÁstanbul
# 9549              Aôôk Kahve         ÛÁstanbul
# 9550  Walter's Coffee Roastery         ÛÁstanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...

# %% [markdown]
# # 4. Relation

# %%
corr=num_feature.corr()

# %%
sns.heatmap(corr[(corr>.3)| (corr<.02)],annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
# Out:
#            Country                Currency
# 0        Australia               Dollar($)
# 1           Brazil      Brazilian Real(R$)
# 2           Canada               Dollar($)
# 3            India      Indian Rupees(Rs.)
# 4        Indonesia  Indonesian Rupiah(IDR)
# 5      New Zealand           NewZealand($)
# 6      Phillipines        Botswana Pula(P)
# 7            Qatar         Qatari Rial(QR)
# 8        Singapore               Dollar($)
# 9     South Africa                 Rand(R)
# 10       Sri Lanka   Sri Lankan Rupee(LKR)
# 11          Turkey        Turkish Lira(TL)
# 12             UAE      Emirati Diram(AED)
# 13  United Kingdom              Pounds(£)
# 14   United States               Dollar($)
